# %% [markdown]
# <a href="https://colab.research.google.com/github/fadhilrobbani/YOLOX/blob/main/cupdetection2yolox.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Copy and extract the dataset from google drive

# %%
# prompt: unzip this zip file from google drive mounted and maybe load to this session: '/content/drive/Colab Notebooks/data/cup-segmentation.v1i.yolov8.zip'
# make somethin like check, if in /content there is folder cup-detection-2 or datasets, remove it first then continue

import zipfile
import os
import shutil

# zip_path = '/content/drive/MyDrive/Colab Notebooks/data/cup-segmentation.v1i.yolov8.zip'
zip_path = '/content/drive/MyDrive/Colab Notebooks/data/cup-detection-v2.1.v1i.voc.zip'

# Define the directory where you want to extract the contents
extract_dir = '/content/datasets' # Changed to a consistent name

# Define potential existing directories to remove
existing_dirs = ['/content/cup-detection-2', '/content/datasets']

# Remove existing directories if they exist
for directory in existing_dirs:
    if os.path.exists(directory):
        print(f"Removing existing directory: {directory}")
        shutil.rmtree(directory)

# Create the extraction directory if it doesn't exist
os.makedirs(extract_dir, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
  zip_ref.extractall(extract_dir)

print(f"Zip file extracted to: {extract_dir}")

# Optional: Change the current working directory to the extracted directory
# This makes it easier to access the extracted files directly.
# %cd {extract_dir}

# Optional: List the contents of the extracted directory to confirm
# !ls
# Out:
# Removing existing directory: /content/datasets
# Zip file extracted to: /content/datasets
# /content/datasets
# README.dataset.txt  README.roboflow.txt  test  train  valid

# %% [markdown]
# ## Clone the repository of YOLOX

# %%
# prompt: this is also update it, because I've just updated the repository in github, you should make check like if there is YOLOX folder, remove it first and reclone

import os
import shutil

repo_dir = 'YOLOX'

# Change to the parent directory before checking for the repository
# %cd /content

# Check if the repository directory exists and remove it
if os.path.exists(repo_dir):
    print(f"Removing existing repository: {repo_dir}")
    shutil.rmtree(repo_dir)

# !git clone https://github.com/fadhilrobbani/YOLOX.git
# Out:
# /content
# Removing existing repository: YOLOX
# Cloning into 'YOLOX'...
# remote: Enumerating objects: 2020, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 2020 (delta 40), reused 51 (delta 24), pack-reused 1938 (from 3)
# Receiving objects: 100% (2020/2020), 7.57 MiB | 15.86 MiB/s, done.
# Resolving deltas: 100% (1189/1189), done.

# %% [markdown]
# ## Download the yolox weight

# %%
# %mkdir YOLOX/weights
# %cd YOLOX/weights
# !wget https://github.com/Megvii-BaseDetection/YOLOX/releases/download/0.1.1rc0/yolox_m.pth
# Out:
# /content/YOLOX/weights
# --2025-09-09 15:50:38--  https://github.com/Megvii-BaseDetection/YOLOX/releases/download/0.1.1rc0/yolox_m.pth
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# ## Install the necessary dependencies

# %%
# !pip install -r requirements.txt
# !pip install -e .
# !pip install cython; pip install 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# !pip install onnx onnxsim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 16.5 MB/s eta 0:00:00
# ...
# Obtaining file:///content/YOLOX
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for yolox
# ...
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-zha5ru7k
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-zha5ru7k
#   Resolved https://github.com/cocodataset/cocoapi.git to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp312-cp312-linux_x86_64.whl size=426683 sha256=b7f6f83e454fa224ee0a97108a17816e7abbe945cc11e52e6796c95e0c7ef4e5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sy35iz8c/wheels/95/e6/c7/8ceda667bca7218619fea052622a0b11a37fb51c28c993fae3
# Successfully built pycocotools
# ...

# %% [markdown]
# ## Convert Pascal VOC from Roboflow to VocDevKit format

# %%
# %cd /content/YOLOX
# Out:
# /content/YOLOX

# %%
# !mkdir -p ./datasets/VOCdevkit/VOC2007/ImageSets/Main
# !mkdir -p ./datasets/VOCdevkit/VOC2007/Annotations
# !mkdir -p ./datasets/VOCdevkit/VOC2007/JPEGImages

# Move all .jpg files from your uploaded 'train', 'test', 'valid' folders
# into the YOLOX-expected JPEGImages directory.
# !mv /content/datasets/train/*.jpg ./datasets/VOCdevkit/VOC2007/JPEGImages/
# !mv /content/datasets/test/*.jpg ./datasets/VOCdevkit/VOC2007/JPEGImages/
# !mv /content/datasets/valid/*.jpg ./datasets/VOCdevkit/VOC2007/JPEGImages/

# Move all .xml files from your uploaded 'train', 'test', 'valid' folders
# into the YOLOX-expected Annotations directory.
# !mv /content/datasets/train/*.xml ./datasets/VOCdevkit/VOC2007/Annotations/
# !mv /content/datasets/test/*.xml ./datasets/VOCdevkit/VOC2007/Annotations/
# !mv /content/datasets/valid/*.xml ./datasets/VOCdevkit/VOC2007/Annotations/


# Generate trainval.txt (list of all image filenames without extension)
# This iterates through all JPG files, extracts their base filename without the .jpg extension, and writes to trainval.txt.
! ( \
for img_path in ./datasets/VOCdevkit/VOC2007/JPEGImages/*.jpg; do \
  filename=$(basename "$img_path" .jpg); \
  echo "$filename"; \
done \
) > ./datasets/VOCdevkit/VOC2007/ImageSets/Main/trainval.txt

# Generate test.txt (can be the same as trainval.txt if you're not using a separate test set)
# This iterates through all JPG files, extracts their base filename without the .jpg extension, and writes to test.txt.
! ( \
for img_path in ./datasets/VOCdevkit/VOC2007/JPEGImages/*.jpg; do \
  filename=$(basename "$img_path" .jpg); \
  echo "$filename"; \
done \
) > ./datasets/VOCdevkit/VOC2007/ImageSets/Main/test.txt

# %% [markdown]
# ## Start the training process

# %%
# !python3 tools/train.py -f exps/example/custom_voc/yolox_voc_m.py -d 1 -b 8 --fp16 -c weights/yolox_m.pth
# Out:
# 2025-09-09 14:40:17.342227: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757428817.368501   28556 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757428817.374542   28556 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1757428817.389695   28556 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ## Convert the .pth model to .onnx

# %%
# !python3 tools/export_onnx.py --output-name cup_yolox.onnx -f exps/example/custom_voc/yolox_voc_m.py -c "/content/drive/MyDrive/Colab Notebooks/trained_models/cup-detection-yolox/yolox_voc_m/best_ckpt.pth"
# Out:
# 2025-09-09 15:51:05.327 | INFO     | __main__:main:64 - args value: Namespace(output_name='cup_yolox.onnx', input='images', output='output', opset=11, batch_size=1, dynamic=False, no_onnxsim=False, exp_file='exps/example/custom_voc/yolox_voc_m.py', experiment_name=None, name=None, ckpt='/content/drive/MyDrive/Colab Notebooks/trained_models/cup-detection-yolox/yolox_voc_m/best_ckpt.pth', opts=[], decode_in_inference=False)
# 2025-09-09 15:51:05.891 | INFO     | __main__:main:88 - loading checkpoint done.
# ...

# %% [markdown]
# ### Save the .onnx to mounted google drive

# %%
# prompt: why it show not a directory

import os

# Define the target directory in Google Drive
target_dir = '/content/drive/MyDrive/Colab Notebooks/trained_models/cup-detection-yolox'

# Create the directory if it doesn't exist
os.makedirs(target_dir, exist_ok=True)

# Copy the ONNX file to the target directory
# !cp /content/YOLOX/cup_yolox.onnx "{target_dir}"
